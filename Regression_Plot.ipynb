# %% [markdown]
# # 📈 Seaborn Regression Plot (`sns.regplot`)
#
# ## ✅ Mục tiêu:
# Vẽ biểu đồ **hồi quy tuyến tính (regression line)** giữa 2 biến số, giúp trực quan hóa mối quan hệ và xu hướng tuyến tính.
#
# ---
#
# ## 📌 Cú pháp đầy đủ:
#
# ```python
# sns.lmplot(
#     x='...', y='...',
#     data=df,
#     hue='...',
#     col='...', row='...',
#     ci=95,
#     palette='Set1',
#     height=5,
#     aspect=1,
#     markers=['o', 'x'],
#     scatter_kws={},
#     line_kws={}
# )
#  📘 Bảng giải thích tham số `sns.lmplot()`
#
# | Tham số         | Kiểu dữ liệu      | Giải thích ngắn gọn |
# |------------------|-------------------|----------------------|
# | `x`, `y`         | str               | Tên cột dữ liệu trục hoành (X) và tung (Y) |
# | `data`           | DataFrame         | Dữ liệu đầu vào chứa các cột `x`, `y`, `hue`,... |
# | `hue`            | str (optional)    | Nhóm phân loại để vẽ đường hồi quy & điểm theo màu khác nhau |
# | `col`, `row`     | str (optional)    | Tạo lưới biểu đồ con (FacetGrid) theo cột hoặc hàng |
# | `ci`             | int hoặc None     | Hiển thị khoảng tin cậy (%) của đường hồi quy (mặc định `95`) |
# | `palette`        | str hoặc dict     | Bảng màu áp dụng cho các nhóm (`hue`) |
# | `height`         | float             | Chiều cao mỗi biểu đồ con (inch) |
# | `aspect`         | float             | Tỉ lệ chiều ngang / chiều cao của biểu đồ |
# | `markers`        | list              | Danh sách ký hiệu điểm cho từng nhóm (vd: `['o', 'x', '^']`) |
# | `scatter_kws`    | dict              | Tùy chỉnh điểm dữ liệu (size, màu, alpha, edgecolor,...) |
# | `line_kws`       | dict              | Tùy chỉnh đường hồi quy (linewidth, linestyle, color,...) |
#
# ---
#
# 📌 Mẹo dùng nhanh:
#
# - `ci=None` → tắt khoảng tin cậy cho đường hồi quy (sạch sẽ hơn)
# - `palette='Set2'` → màu đẹp cho phân nhóm
# - `markers=['o', 'x']` → dễ phân biệt nhóm
# - `height=5, aspect=1.2` → điều chỉnh kích thước mỗi biểu đồ con
#
# ---
#
# 🧪 Ví dụ:
#
# ```python
# sns.lmplot(
#     x='total_bill',
#     y='tip',
#     data=df,
#     hue='sex',
#     col='time',
#     palette='Set2',
#     markers=['o', 's'],
#     ci=None,
#     height=5,
#     aspect=1.2,
#     scatter_kws={'s': 60, 'alpha': 0.7},
#     line_kws={'linewidth': 2, 'linestyle': '--'}
# )

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('car_crashes')
df.head(3)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ

# %%
sns.lmplot( x="alcohol",
           y="ins_premium",
           data=df,
           palette="Dark2",
           height=5,
           aspect=1
           )
plt.title("Mối quan hệ giữa Nồng độ cồn và Phí bảo hiểm")
plt.xlabel("Tỷ lệ tài xế ảnh hưởng bởi cồn (%)")
plt.ylabel("Phí bảo hiểm($)")
# Out:
# Text(15.890625000000009, 0.5, 'Phí bảo hiểm($)')

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.lmplot(
    x = 'total_bill',
    y = 'tip',
    palette=['red', 'b'],
    data = tips,
    hue = 'time',
    # row = 'time',
    # col = 'smoker',
    row = 'day',
    col = 'sex',
    markers = ['o', 's'],
    height=4,
    aspect=1,
    scatter_kws={'s': 60, 'alpha': 0.7},
    line_kws={'linewidth': 2, 'linestyle': '--'}
)
